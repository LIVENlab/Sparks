# %%
from Sparks.util.base import SoftLink


enbios_mod = SoftLink(r'C:\Users\1496051\PycharmProjects\Sparks_local\testing\data_test\flow_out_sum.csv',
                      r'C:\Users\1496051\PycharmProjects\Sparks_local\testing\data_test\basefile.xlsx',
                       'github_3',
                      'ecoinvent')

enbios_mod.preprocess(subregions=False)
enbios_mod.data_for_ENBIOS(smaller_vers=True,
                           path_save=r'test.json')
# Out:
# WARNING:root:Testing logging messages
# Project and Database existing...
# Adapting input data...
# C:\Users\1496051\PycharmProjects\Sparks_local\Sparks\util\preprocess\cleaner.py:122: Warning:
# The following technologies, are present in the energy data but not in the Basefile:
#
# {'gas_hob', 'h2_import', 'hp', 'hydrogen_to_liquids', 'dac', 'heavy_transport_ev', 'hydrogen_to_methanol', 'light_transport_ice', 'heavy_transport_ice', 'electric_hob', 'hydrogen_storage', 'electric_heater', 'hydrogen_to_methane', 'biofuel_supply', 'light_transport_ev'}
#
#  Please,check the following items in order to avoid missing information
#   warnings.warn(message,Warning)
# C:\Users\1496051\PycharmProjects\Sparks_local\Sparks\generic\generic_dataclass.py:48: Warning:
# ssss not found in the database. Please check your database / basefile.
# This activity won't be included.
#   warnings.warn(message, Warning)
# C:\Users\1496051\PycharmProjects\Sparks_local\Sparks\generic\generic_dataclass.py:48: Warning:
# CHP_hydrogen_2050 not found in the database. Please check your database / basefile.
# This activity won't be included.
#   warnings.warn(message, Warning)
# C:\Users\1496051\PycharmProjects\Sparks_local\Sparks\generic\generic_dataclass.py:48: Warning:
# CHP_hydrogen_2050_HEAT_1 not found in the database. Please check your database / basefile.
# This activity won't be included.
#   warnings.warn(message, Warning)
# C:\Users\1496051\PycharmProjects\Sparks_local\Sparks\generic\generic_dataclass.py:48: Warning:
# market_hydrogen_2050 not found in the database. Please check your database / basefile.
# This activity won't be included.
#   warnings.warn(message, Warning)
# function preprocess executed in 0.9645016193389893 seconds
# Input data for ENBIOS created

# %%
# Out:
# Creating logging config file at: C:\Users\1496051\PycharmProjects\Sparks_local\venv\Lib\site-packages\enbios\data\logging.json

# %%
import enbios as enb
#from enbios2.base.experiment import Experiment
import json


exp = enb.Experiment(r'C:\Users\1496051\PycharmProjects\Sparks_local\testing\demos\test.json')
exp.run()
# Out:
# 2024-07-17 16:26:16,278 - ............enbios.base - INFO - Running scenario '0'
# {'0': {'name': 'Energysystem',
#   'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#     'magnitude': 21290874550.891167},
#    'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 4891099818.182154},
#    'WCP': {'unit': 'cubic meter', 'magnitude': 520280683.5979848},
#    'FEP': {'unit': 'kg P-Eq', 'magnitude': 5331082.45898181},
#    'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 555656988.7344484}},
#   'output': [{'unit': 'kilowatt_hour',
#     'magnitude': 209010810750.8053,
#     'label': None},
#    {'unit': 'kilogram', 'magnitude': 1002710706.0983341, 'label': None},
#    {'unit': 'unspecificEcoinventUnit',
#     'magnitude': 725.6487839429126,
#     'label': None},
#    {'unit': 'meter ** 3', 'magnitude': 240964492.04181156, 'label': None}],
#   'children': [{'name': 'Generation',
#     'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#       'magnitude': 8829503207.109735},
#      'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2402745433.2661505},
#      'WCP': {'unit': 'cubic meter', 'magnitude': 439184031.6490956},
#      'FEP': {'unit': 'kg P-Eq', 'magnitude': 3754094.8492943603},
#      'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 462229543.5620682}},
#     'output': [{'unit': 'kilowatt_hour',
#       'magnitude': 195000718875.634,
#       'label': None}],
#     'children': [{'name': 'Electricity_generation',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 8828785168.378191},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2402570611.1698003},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 439183483.4253469},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 3754086.143736052},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 462228713.1001076}},
#       'output': [{'unit': 'kilowatt_hour',
#         'magnitude': 194997809074.0435,
#         'label': None}],
#       'children': [{'name': 'wind_onshore__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 839232944.7454091},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 58694939.56217622},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 7507259.878165366},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 360956.8968052059},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 117824611.54299878}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 57514890465.62103,
#           'label': None}],
#         'bw_activity_code': '81174ec2c20931c1a36f65c654bbd11e'},
#        {'name': 'hydro_run_of_river__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 35935814.397402},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1457463.6966543603},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 176752.37292908947},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 8762.645194505696},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 3421335.149335462}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 8217716366.150942,
#           'label': None}],
#         'bw_activity_code': 'b870e3d3ddd5b634d016940064b27532'},
#        {'name': 'hydro_reservoir__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 366301465.3454201},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 771615.2856067385},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 205751059.38652915},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 9543.920527413125},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 2360273.5786696766}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 7034481419.237691,
#           'label': None}],
#         'bw_activity_code': 'c868c4688fbf78f5ca3787ac3d83312b'},
#        {'name': 'ccgt__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 12419.652633006563},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 14.553172519852945},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 21.15154148267967},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.22098320744285094},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 91.43922111227818}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 23211.124751186187,
#           'label': None}],
#         'bw_activity_code': '4833b6352dfe15c95ae46fd280371cd3'},
#        {'name': 'chp_biofuel_extraction__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 251836.9982524042},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 62813.557958859914},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 186.19593113277728},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 3.004893680224827},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 255.0028475375588}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 158962.74804907836,
#           'label': None}],
#         'bw_activity_code': '1952fb157a18463b0028629917057bcf'},
#        {'name': 'open_field_pv__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 6740766814.595654},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2285152552.73823},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 219381428.507733},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 3190969.4287062306},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 298328909.1684811}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 100417087878.80571,
#           'label': None}],
#         'bw_activity_code': '206c2e2c30f45d47ea2e9a3701f8ecc5'},
#        {'name': 'existing_wind__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 247699593.82150978},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 17323810.7181036},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 2215767.665193033},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 106536.42386874728},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 34775932.71796037}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 16975519247.851534,
#           'label': None}],
#         'bw_activity_code': '81174ec2c20931c1a36f65c654bbd11e'},
#        {'name': 'existing_pv__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 114558818.53296815},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 38835993.56249023},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 3728370.666006183},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 54230.28236726954},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 5070077.0860662395}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 1706580759.1818905,
#           'label': None}],
#         'bw_activity_code': '206c2e2c30f45d47ea2e9a3701f8ecc5'},
#        {'name': 'roof_mounted_pv__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 55027.11790940737},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1535.2994357999664},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 1850.8841320719516},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 33.58037619239784},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 2091.8208761620976}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 842273.1367537137,
#           'label': None}],
#         'bw_activity_code': '1d7a3591e7a3d033a25e0eaf699bb50b'},
#        {'name': 'chp_wte_back_pressure__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 86288902.77319002},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 48112.63464363462},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 75017.63871969024},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 4109.822201037709},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 79322.98648495642}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 558172222.4720111,
#           'label': None}],
#         'bw_activity_code': '07d4d5423ba8379958ee341ada3a6ef5'},
#        {'name': 'chp_methane_extraction__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 36817.15733747915},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 42.35106207377302},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 65.67422847015513},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.6449967192767114},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 268.89064828444515}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 114044.33980325895,
#           'label': None}],
#         'bw_activity_code': 'a0d0ab65435d0487d33b4be142483d76'},
#        {'name': 'waste_supply__waste___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 397644713.24050695},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 221717.2102659638},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 345703.4042382003},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 18939.272815842178},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 365543.716517931}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 2572222223.3733234,
#           'label': None}],
#         'bw_activity_code': '07d4d5423ba8379958ee341ada3a6ef5'}]},
#      {'name': 'Thermal_generation',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 718038.7315447938},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 174822.09635035766},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 548.2237487126486},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 8.705558308335437},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 830.4619606233122}},
#       'output': [{'unit': 'megajoule',
#         'magnitude': 10475285.72580594,
#         'label': None}],
#       'children': [{'name': 'chp_biofuel_extraction__heat___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 70323.09020248591},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 17540.089626458463},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 51.99344596720224},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.8390880351960961},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 71.20712334381841}},
#         'output': [{'unit': 'megajoule',
#           'magnitude': 941785.54105752,
#           'label': None}],
#         'bw_activity_code': '413bc4617794c6e8b07038dbeca64adb'},
#        {'name': 'chp_wte_back_pressure__heat___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 770.3812970392913},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 0.473412017573462},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 0.7445164239238091},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.055357898685589685},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 0.7824346965614929}},
#         'output': [{'unit': 'megajoule',
#           'magnitude': 94617.4063238808,
#           'label': None}],
#         'bw_activity_code': 'bbcc24a62a7a425e708fa8967f0df2ee'},
#        {'name': 'chp_methane_extraction__heat___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 2436.916595511942},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2.803204052218657},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 4.346957632638193},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.04269214031943544},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 17.79779181149822}},
#         'output': [{'unit': 'megajoule',
#           'magnitude': 147518.0183137525,
#           'label': None}],
#         'bw_activity_code': 'a3039e0a35ed472774d6ed66262c67f3'},
#        {'name': 'biofuel_boiler__heat___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 630509.5442613801},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 157262.62718032647},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 466.16785221302007},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 7.523176428601771},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 638.4356936916769}},
#         'output': [{'unit': 'megajoule',
#           'magnitude': 8443951.632043561,
#           'label': None}],
#         'bw_activity_code': '413bc4617794c6e8b07038dbeca64adb'},
#        {'name': 'methane_boiler__heat___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 13998.79918837665},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 16.102927502938353},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 24.97097647586434},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.24524380553254455},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 102.23891707975709}},
#         'output': [{'unit': 'megajoule',
#           'magnitude': 847413.1280672245,
#           'label': None}],
#         'bw_activity_code': 'a3039e0a35ed472774d6ed66262c67f3'}]}]},
#    {'name': 'Storage',
#     'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#       'magnitude': 5546125653.145517},
#      'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 187699069.3624614},
#      'WCP': {'unit': 'cubic meter', 'magnitude': 41320793.2337443},
#      'FEP': {'unit': 'kg P-Eq', 'magnitude': 1134892.8903092432},
#      'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 69427078.71384138}},
#     'output': [{'unit': 'kilogram',
#       'magnitude': 44134.16580352975,
#       'label': None},
#      {'unit': 'kilowatt_hour', 'magnitude': 9180843870.236614, 'label': None},
#      {'unit': 'unspecificEcoinventUnit',
#       'magnitude': 725.6487839429126,
#       'label': None}],
#     'children': [{'name': 'Electricity_storage',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 5310298756.023119},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 137471423.80251956},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 39993458.16303293},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 1002436.5748733113},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 37044614.65885797}},
#       'output': [{'unit': 'kilogram',
#         'magnitude': 44134.16580352975,
#         'label': None},
#        {'unit': 'kilowatt_hour',
#         'magnitude': 9180843870.236614,
#         'label': None}],
#       'children': [{'name': 'battery__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 762524.3918046472},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 27708.9143482835},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 35041.16398379878},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 592.1167258403841},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 247340.29200837621}},
#         'output': [{'unit': 'kilogram',
#           'magnitude': 44134.16580352975,
#           'label': None}],
#         'bw_activity_code': '5649dd9b7aa34f1a93f87fabfb7ea516'},
#        {'name': 'pumped_hydro__electricity___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 5309536231.631314},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 137443714.8881713},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 39958416.99904913},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1001844.458147471},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 36797274.366849594}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 9180843870.236614,
#           'label': None}],
#         'bw_activity_code': '309ff1f1194f2b5ea34d8c077103b1e3'}]},
#      {'name': 'Thermal_storage',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 235826897.12239847},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 50227645.55994184},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 1327335.070711374},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 132456.31543593184},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 32382464.054983415}},
#       'output': [{'unit': 'unspecificEcoinventUnit',
#         'magnitude': 725.6487839429126,
#         'label': None}],
#       'children': [{'name': 'heat_storage_big__heat___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 30792.82154849129},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2592.553148000541},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 278.8670388224502},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 12.559348914205401},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 5954.340564586386}},
#         'output': [{'unit': 'unspecificEcoinventUnit',
#           'magnitude': 27.51374451906663,
#           'label': None}],
#         'bw_activity_code': '07db2c419abe9cffeb033aa0bed7f0ba'},
#        {'name': 'heat_storage_small__heat___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 613672.9194880653},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 32233.898794612905},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 5422.9003607313925},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 244.03199833249516},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 111486.50720065701}},
#         'output': [{'unit': 'unspecificEcoinventUnit',
#           'magnitude': 676.8670753979804,
#           'label': None}],
#         'bw_activity_code': '14e0227e764a4a098e5fd34525ccaf3f'},
#        {'name': 'methane_storage__methane___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 235182431.3813619},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 50192819.10799923},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 1321633.3033118201},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 132199.72408868515},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 32265023.20721817}},
#         'output': [{'unit': 'unspecificEcoinventUnit',
#           'magnitude': 21.26796402586542,
#           'label': None}],
#         'bw_activity_code': 'da586847dea594ccd75188627f456d03'}]}]},
#    {'name': 'Conversions',
#     'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#       'magnitude': 5541917513.117828},
#      'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2271435147.5213156},
#      'WCP': {'unit': 'cubic meter', 'magnitude': 27719922.185770825},
#      'FEP': {'unit': 'kg P-Eq', 'magnitude': 202581.48870901234},
#      'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 12097256.09333844}},
#     'output': [{'unit': 'kilogram',
#       'magnitude': 1002666571.9325305,
#       'label': None},
#      {'unit': 'meter ** 3', 'magnitude': 240964492.04181156, 'label': None}],
#     'children': [{'name': 'Conversions',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 5541917513.117828},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2271435147.5213156},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 27719922.185770825},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 202581.48870901234},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 12097256.09333844}},
#       'output': [{'unit': 'kilogram',
#         'magnitude': 1002666571.9325305,
#         'label': None},
#        {'unit': 'meter ** 3', 'magnitude': 240964492.04181156, 'label': None}],
#       'children': [{'name': 'biofuel_to_diesel__diesel___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 861764955.4861757},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1056700505.1865565},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 18080786.7201832},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 88896.80846000796},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 4644329.276454667}},
#         'output': [{'unit': 'kilogram',
#           'magnitude': 226141452.37025702,
#           'label': None}],
#         'bw_activity_code': '3a6586952eff793738eef72743703e90'},
#        {'name': 'biofuel_to_liquids__diesel___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 102039.83828380975},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 125121.7608410928},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 2140.9092365768975},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 10.526090556721806},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 549.9255978751021}},
#         'output': [{'unit': 'kilogram',
#           'magnitude': 26776.950120781345,
#           'label': None}],
#         'bw_activity_code': '3a6586952eff793738eef72743703e90'},
#        {'name': 'biofuel_to_methane__methane___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 343073632.12106514},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 10327214.030221842},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 814786.5849414427},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 6068.8610511762145},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 745039.3638742774}},
#         'output': [{'unit': 'meter ** 3',
#           'magnitude': 240964492.04181156,
#           'label': None}],
#         'bw_activity_code': '7d82a9b0a28dc30058260b5c68fbad95'},
#        {'name': 'biofuel_to_methanol__methanol___PRT',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 4336976885.672303},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1204282306.543696},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 8822207.971409606},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 107605.29310727144},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 6707337.52741162}},
#         'output': [{'unit': 'kilogram',
#           'magnitude': 776498342.6121527,
#           'label': None}],
#         'bw_activity_code': 'df54a237474430370bb580c2451d405d'}]}]},
#    {'name': 'Imports',
#     'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#       'magnitude': 1373328177.518085},
#      'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 29220168.032226156},
#      'WCP': {'unit': 'cubic meter', 'magnitude': 12055936.529374091},
#      'FEP': {'unit': 'kg P-Eq', 'magnitude': 239513.23066919504},
#      'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 11903110.365200447}},
#     'output': [{'unit': 'kilowatt_hour',
#       'magnitude': 4829248004.934705,
#       'label': None}],
#     'children': [{'name': 'Imports',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 1373328177.518085},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 29220168.032226156},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 12055936.529374091},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 239513.23066919504},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 11903110.365200447}},
#       'output': [{'unit': 'kilowatt_hour',
#         'magnitude': 4829248004.934705,
#         'label': None}],
#       'children': [{'name': 'el_import__electricity___ESP',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 1373328177.518085},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 29220168.032226156},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 12055936.529374091},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 239513.23066919504},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 11903110.365200447}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 4829248004.934705,
#           'label': None}],
#         'bw_activity_code': '1373b63314d03c42313a372bca1bd648'}]}]}]}}
